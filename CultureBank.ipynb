# %% [markdown]
# <a href="https://colab.research.google.com/github/raj15019/CultureBank-main/blob/main/CultureBank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/raj15019/CultureBank-main.git
# Out:
# Cloning into 'CultureBank-main'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 73 (delta 18), reused 64 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 832.21 KiB | 7.63 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# !conda --version
# Out:
# /bin/bash: line 1: conda: command not found

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# !pwd
# !ls
# Out:
# /content
# condacolab_install.log	CultureBank-main  sample_data

# %%
# %cd /content/CultureBank-main
# Out:
# /content/CultureBank-main

# %%
# !conda env create -f environment.yml
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# mkl-2023.1.0         | 171.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
# pytorch-2.3.0        | 76.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# python-3.11.4        | 32.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# intel-openmp-2023.1. | 17.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# gh-2.36.0            | 15.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# icu-58.2             | 10.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# numpy-base-1.25.2    | 8.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# openssl-3.0.11       | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !python data_process_pipeline/main.py -i 0,1,3,4,5,6,7,8 -c ./data_process_pipeline/configs/config_dummy_data_vanilla_mistral.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/CultureBank-main/data_process_pipeline/main.py", line 7, in <module>
#     from utils.config_reader import read_config
#   File "/content/CultureBank-main/data_process_pipeline/utils/config_reader.py", line 4, in <module>
#     import yaml
# ModuleNotFoundError: No module named 'yaml'

# %%
# !python data_process_pipeline/main.py -i 0 -c /content/CultureBank-main/data_process_pipeline/configs/config_dummy_data_vanilla_mistral.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/CultureBank-main/data_process_pipeline/main.py", line 9, in <module>
#     from pipeline.main_pipeline import CultureBankPipeline
#   File "/content/CultureBank-main/data_process_pipeline/pipeline/main_pipeline.py", line 4, in <module>
#     from data_process_pipeline.pipeline.component_2_negation_converter import (
# ModuleNotFoundError: No module named 'data_process_pipeline'

# %%
# !pip3 list
# Out:
# Package                 Version
# ----------------------- ----------
# archspec                0.2.2
# boltons                 23.1.1
# Brotli                  1.1.0
# certifi                 2023.11.17
# cffi                    1.16.0
# charset-normalizer      3.3.2
# colorama                0.4.6
# conda                   23.11.0
# conda-libmamba-solver   23.12.0
# conda-package-handling  2.2.0
# conda_package_streaming 0.9.0
# distro                  1.8.0
# idna                    3.6
# jsonpatch               1.33
# jsonpointer             2.4
# libmambapy              1.5.5
# mamba                   1.5.5
# menuinst                2.0.1
# packaging               23.2
# pip                     23.3.2
# platformdirs            4.1.0
# pluggy                  1.3.0
# pycosat                 0.6.6
# pycparser               2.21
# PySocks                 1.7.1
# requests                2.31.0
# ruamel.yaml             0.18.5
# ruamel.yaml.clib        0.2.7
# ...

# %%
# !conda update -n base -c conda-forge conda
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.12.14 |       hbcca054_0         153 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
# !conda init
# !conda activate culturebank
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
#
# CondaError: Run 'conda init' before 'conda activate'

# %%
# !pip install spacy
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.1/29.1 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.7/204.7 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 82.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.0/457.0 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 78.0 MB/s eta 0:00:00
# ...

# %%
# !conda install pyyaml --channel conda-forge
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pyyaml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.12.14 |       hbcca054_0         153 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 261 bytes | 261.00 KiB/s, done.
# From https://github.com/raj15019/CultureBank-main
#    fc86faf..2e4cd5f  main       -> origin/main
# Updating fc86faf..2e4cd5f
# Fast-forward
#  environment.yml | 1 -
#  1 file changed, 1 deletion(-)
